# %%
#dbutils.library.installPyPI("koalas")
#dbutils.library.restartPython()

import databricks.koalas as ks

a = ks.read_csv("/FileStore/tables/sklearn_1n_nodectree_20200310.csv")    

display(a.to_spark())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
